# %% [markdown]
# ## 3가지 데이터 join

# %%
import pandas as pd

articles = pd.read_csv('./data/cleaned_articles_hm.csv') # Article_Id
customer = pd.read_csv('./data/cleaned_customer_hm.csv') # Customer_Id
transactions = pd.read_csv('./data/cleaned_transactions_hm.csv') # 메인 테이블

# %%
merged_df = transactions.merge(articles, on='Article_Id', how='inner') \
                        .merge(customer, on='Customer_Id', how='inner')
merged_df.head()
# Out:
#         T_Dat                                        Customer_Id  Article_Id  \
# 0  2019-11-05  3e2b60b679e62fb49516105b975560082922011dd752ec...   698328010
# 1  2019-05-22  89647ac2274f54c770aaa4b326e0eea09610c252381f37...   760597002
# 2  2019-05-10  2ebe392150feb60ca89caa8eff6c08b7ef1138cd6fdc71...   488561032
# 3  2019-08-26  7b3205de4ca17a339624eb5e3086698e9984eba6b47c56...   682771001
# 4  2019-08-10  3b77905de8b32045f08cedb79200cdfa477e9562429a39...   742400033
#
#       Price  Sales_Channel_Id  Month   Day_name  Revenue  Product_Code  \
# 0  0.016932                 2     11    Tuesday    16932        698328
# 1  0.033881                 2      5  Wednesday    33881        760597
# 2  0.016932                 2      5     Friday    16932        488561
# 3  0.033881                 2      8     Monday    33881        682771
# 4  0.003220                 1      8   Saturday     3220        742400
#
#          Prod_Name  ...              Index_Info Index_Group_Info  \
# 0     ZEBRA CF TVP  ...             Divided (D)      Divided (2)
# 1  BUBBLE WRAP TOP  ...          Ladieswear (A)   Ladieswear (1)
# 2    Teddy jogger.  ...            Menswear (F)     Menswear (3)
# 3     Yuki shopper  ...  Ladies Accessories (C)   Ladieswear (1)
# 4    1pk Sportsock  ...            Menswear (F)     Menswear (3)
#
#                   Section_Info       Garment_Group_Info FN Active  \
# 0      Divided Collection (53)      Jersey Fancy (1005)  1      1
# 1            Womens Casual (6)      Jersey Fancy (1005)  0      0
# 2     Contemporary Casual (21)            Shorts (1025)  1      1
# 3  Womens Big accessories (65)       Accessories (1019)  0      0
# 4           Men Underwear (26)  Socks and Tights (1021)  0      0
#
#   Club_Member_Status Fashion_News_Frequency Age  Age_Group
# 0             Active              Regularly  51         50
# 1             Active                    NaN  28         20
# 2             Active              Regularly  37         30
# 3             Active                    NaN  19         10
# 4             Active                    NaN  35         30
#
# [5 rows x 25 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 804149 entries, 0 to 804148
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   T_Dat                         804149 non-null  str
#  1   Customer_Id                   804149 non-null  str
#  2   Article_Id                    804149 non-null  int64
#  3   Price                         804149 non-null  float64
#  4   Sales_Channel_Id              804149 non-null  int64
#  5   Month                         804149 non-null  int64
#  6   Day_name                      804149 non-null  str
#  7   Revenue                       804149 non-null  int64
#  8   Product_Code                  804149 non-null  int64
#  9   Prod_Name                     804149 non-null  str
#  10  Product_Type_Info             804149 non-null  str
#  11  Product_Group_Name            804149 non-null  str
#  12  Graphical_Appearance_Info     804149 non-null  str
#  13  Perceived_Colour_Master_Info  804149 non-null  str
#  14  Department_Info               804149 non-null  str
#  15  Index_Info                    804149 non-null  str
#  16  Index_Group_Info              804149 non-null  str
#  17  Section_Info                  804149 non-null  str
#  18  Garment_Group_Info            804149 non-null  str
#  19  FN                            804149 non-null  int64
#  20  Active                        804149 non-null  int64
#  21  Club_Member_Status            804149 non-null  str
#  22  Fashion_News_Frequency        347984 non-null  str
#  23  Age                           804149 non-null  int64
#  24  Age_Group                     804149 non-null  int64
# dtypes: float64(1), int64(9), str(15)
# memory usage: 153.4 MB

# %%
merged_df.shape
# Out:
# (804149, 25)

# %% [markdown]
# ## (804149, 25)

# %%
merged_df.isna().sum()
# Out:
# T_Dat                                0
# Customer_Id                          0
# Article_Id                           0
# Price                                0
# Sales_Channel_Id                     0
# Month                                0
# Day_name                             0
# Revenue                              0
# Product_Code                         0
# Prod_Name                            0
# Product_Type_Info                    0
# Product_Group_Name                   0
# Graphical_Appearance_Info            0
# Perceived_Colour_Master_Info         0
# Department_Info                      0
# Index_Info                           0
# Index_Group_Info                     0
# Section_Info                         0
# Garment_Group_Info                   0
# FN                                   0
# Active                               0
# Club_Member_Status                   0
# Fashion_News_Frequency          456165
# Age                                  0
# Age_Group                            0
# dtype: int64

# %%
merged_df['Fashion_News_Frequency'] = merged_df['Fashion_News_Frequency'].fillna('None')

merged_df.head()
# Out:
#         T_Dat                                        Customer_Id  Article_Id  \
# 0  2019-11-05  3e2b60b679e62fb49516105b975560082922011dd752ec...   698328010
# 1  2019-05-22  89647ac2274f54c770aaa4b326e0eea09610c252381f37...   760597002
# 2  2019-05-10  2ebe392150feb60ca89caa8eff6c08b7ef1138cd6fdc71...   488561032
# 3  2019-08-26  7b3205de4ca17a339624eb5e3086698e9984eba6b47c56...   682771001
# 4  2019-08-10  3b77905de8b32045f08cedb79200cdfa477e9562429a39...   742400033
#
#       Price  Sales_Channel_Id  Month   Day_name  Revenue  Product_Code  \
# 0  0.016932                 2     11    Tuesday    16932        698328
# 1  0.033881                 2      5  Wednesday    33881        760597
# 2  0.016932                 2      5     Friday    16932        488561
# 3  0.033881                 2      8     Monday    33881        682771
# 4  0.003220                 1      8   Saturday     3220        742400
#
#          Prod_Name  ...              Index_Info Index_Group_Info  \
# 0     ZEBRA CF TVP  ...             Divided (D)      Divided (2)
# 1  BUBBLE WRAP TOP  ...          Ladieswear (A)   Ladieswear (1)
# 2    Teddy jogger.  ...            Menswear (F)     Menswear (3)
# 3     Yuki shopper  ...  Ladies Accessories (C)   Ladieswear (1)
# 4    1pk Sportsock  ...            Menswear (F)     Menswear (3)
#
#                   Section_Info       Garment_Group_Info FN Active  \
# 0      Divided Collection (53)      Jersey Fancy (1005)  1      1
# 1            Womens Casual (6)      Jersey Fancy (1005)  0      0
# 2     Contemporary Casual (21)            Shorts (1025)  1      1
# 3  Womens Big accessories (65)       Accessories (1019)  0      0
# 4           Men Underwear (26)  Socks and Tights (1021)  0      0
#
#   Club_Member_Status Fashion_News_Frequency Age  Age_Group
# 0             Active              Regularly  51         50
# 1             Active                   None  28         20
# 2             Active              Regularly  37         30
# 3             Active                   None  19         10
# 4             Active                   None  35         30
#
# [5 rows x 25 columns]

# %%
merged_df.isna().sum()
# Out:
# T_Dat                           0
# Customer_Id                     0
# Article_Id                      0
# Price                           0
# Sales_Channel_Id                0
# Month                           0
# Day_name                        0
# Revenue                         0
# Product_Code                    0
# Prod_Name                       0
# Product_Type_Info               0
# Product_Group_Name              0
# Graphical_Appearance_Info       0
# Perceived_Colour_Master_Info    0
# Department_Info                 0
# Index_Info                      0
# Index_Group_Info                0
# Section_Info                    0
# Garment_Group_Info              0
# FN                              0
# Active                          0
# Club_Member_Status              0
# Fashion_News_Frequency          0
# Age                             0
# Age_Group                       0
# dtype: int64

# %% [markdown]
# ### 매출 상위 20%, 하위 20% 태그

# %%
customer_revenue = merged_df.groupby('Customer_Id')['Revenue'].sum().reset_index()

# %%
top = customer_revenue['Revenue'].quantile(0.8) # 매출 80% 지점이 어디인지
bottom = customer_revenue['Revenue'].quantile(0.2) # 매출 20% 지점이 어디인지

# %%
top_20 = customer_revenue[customer_revenue['Revenue'] >= top]
bottom_20 = customer_revenue[customer_revenue['Revenue'] <= bottom]

# %%
print(f"전체 고객 수: {len(customer_revenue)}명")
print(f"상위 20% 고객 수: {len(top_20)}명")
print(f"상위 20% 최소 매출액: {top}")

print(f"하위 20% 고객 수: {len(bottom_20)}명")
print(f"하위 20% 최대 매출액: {bottom}")
# Out:
# 전체 고객 수: 351503명
# 상위 20% 고객 수: 70315명
# 상위 20% 최소 매출액: 86387.0
# 하위 20% 고객 수: 70708명
# 하위 20% 최대 매출액: 16932.0

# %%
total_revenue = customer_revenue['Revenue'].sum()
top_20_total_revenue = top_20['Revenue'].sum()

ratio = (top_20_total_revenue / total_revenue) * 100
print(f"상위 20% 고객의 매출 비중: {ratio:.2f}%")
# Out:
# 상위 20% 고객의 매출 비중: 52.75%

# %%
# Out:
#                                               Customer_Id  Revenue
# 0       00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...   105050
# 1       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...   199895
# 2       0000757967448a6cb83efb3ea7a3fb9d418ac7adf2379d...    25406
# 3       00007d2de826758b65a93dd24ce629ed66842531df6699...   103726
# 4       00009d946eec3ea54add5ba56d5210ea898def4b46c685...   141337
# ...                                                   ...      ...
# 351498  c88f00357e7b1518128c80043e5d2b223308a3ce3fc389...    59305
# 351499  c88f0d813c429ceb32683c9cb5fcb24331ff198e6e17f2...    16932
# 351500  c88f5971612e659a4e90d6f08d9c29bdf1e4268fcf52d5...    40982
# 351501  c88f99a55b10f6dd50dd87c3ca05af4a8a6c98f3e6fbc5...    64355
# 351502  c88fa15c06519c4bdcab386fea313b226113584b729874...    22016
#
# [351503 rows x 2 columns]

# %%
import numpy as np

# 0~1 사이의 백분위수 계산 (1에 가까울수록 고매출)
customer_revenue['percentile'] = customer_revenue['Revenue'].rank(pct=True)

# 조건 설정
# 상위 20% = percentile 0.8 이상
# 하위 20% = percentile 0.2 이하
conditions = [
    (customer_revenue['percentile'] >= 0.8),
    (customer_revenue['percentile'] <= 0.2)
]
choices = ['Top_20', 'Bottom_20']

# 'Segment' 컬럼 생성 (나머지는 'Middle'로 채움)
customer_revenue['Segment'] = np.select(conditions, choices, default='Middle')

# %%
customer_revenue
# Out:
#                                               Customer_Id  Revenue  \
# 0       00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...   105050
# 1       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...   199895
# 2       0000757967448a6cb83efb3ea7a3fb9d418ac7adf2379d...    25406
# 3       00007d2de826758b65a93dd24ce629ed66842531df6699...   103726
# 4       00009d946eec3ea54add5ba56d5210ea898def4b46c685...   141337
# ...                                                   ...      ...
# 351498  c88f00357e7b1518128c80043e5d2b223308a3ce3fc389...    59305
# 351499  c88f0d813c429ceb32683c9cb5fcb24331ff198e6e17f2...    16932
# 351500  c88f5971612e659a4e90d6f08d9c29bdf1e4268fcf52d5...    40982
# 351501  c88f99a55b10f6dd50dd87c3ca05af4a8a6c98f3e6fbc5...    64355
# 351502  c88fa15c06519c4bdcab386fea313b226113584b729874...    22016
#
#         percentile    Segment
# 0         0.851848     Top_20
# 1         0.959137     Top_20
# 2         0.302857     Middle
# 3         0.849471     Top_20
# 4         0.912696     Top_20
# ...            ...        ...
# 351498    0.669616     Middle
# 351499    0.172401  Bottom_20
# 351500    0.504215     Middle
# 351501    0.692129     Middle
# 351502    0.240870     Middle
#
# [351503 rows x 4 columns]

# %%
merged_df = pd.merge(merged_df, customer_revenue[['Customer_Id', 'Segment']], on='Customer_Id', how='inner')

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 804149 entries, 0 to 804148
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   T_Dat                         804149 non-null  str
#  1   Customer_Id                   804149 non-null  str
#  2   Article_Id                    804149 non-null  int64
#  3   Price                         804149 non-null  float64
#  4   Sales_Channel_Id              804149 non-null  int64
#  5   Month                         804149 non-null  int64
#  6   Day_name                      804149 non-null  str
#  7   Revenue                       804149 non-null  int64
#  8   Product_Code                  804149 non-null  int64
#  9   Prod_Name                     804149 non-null  str
#  10  Product_Type_Info             804149 non-null  str
#  11  Product_Group_Name            804149 non-null  str
#  12  Graphical_Appearance_Info     804149 non-null  str
#  13  Perceived_Colour_Master_Info  804149 non-null  str
#  14  Department_Info               804149 non-null  str
#  15  Index_Info                    804149 non-null  str
#  16  Index_Group_Info              804149 non-null  str
#  17  Section_Info                  804149 non-null  str
#  18  Garment_Group_Info            804149 non-null  str
#  19  FN                            804149 non-null  int64
#  20  Active                        804149 non-null  int64
#  21  Club_Member_Status            804149 non-null  str
#  22  Fashion_News_Frequency        804149 non-null  str
#  23  Age                           804149 non-null  int64
#  24  Age_Group                     804149 non-null  int64
#  25  Segment                       804149 non-null  str
# dtypes: float64(1), int64(9), str(16)
# memory usage: 159.5 MB

# %%
merged_df.shape
# Out:
# (804149, 26)

# %% [markdown]
# ### (804149, 26)
# 컬럼 수만 1개 늘어나고 전체 행 수 변화 없음 (Segment 컬럼 1개 늘어남)

# %%
merged_df.isna().sum()
# Out:
# T_Dat                           0
# Customer_Id                     0
# Article_Id                      0
# Price                           0
# Sales_Channel_Id                0
# Month                           0
# Day_name                        0
# Revenue                         0
# Product_Code                    0
# Prod_Name                       0
# Product_Type_Info               0
# Product_Group_Name              0
# Graphical_Appearance_Info       0
# Perceived_Colour_Master_Info    0
# Department_Info                 0
# Index_Info                      0
# Index_Group_Info                0
# Section_Info                    0
# Garment_Group_Info              0
# FN                              0
# Active                          0
# Club_Member_Status              0
# Fashion_News_Frequency          0
# Age                             0
# Age_Group                       0
# Segment                         0
# dtype: int64

# %% [markdown]
# ### 결측치 없음

# %%
merged_df.head()
# Out:
#         T_Dat                                        Customer_Id  Article_Id  \
# 0  2019-11-05  3e2b60b679e62fb49516105b975560082922011dd752ec...   698328010
# 1  2019-05-22  89647ac2274f54c770aaa4b326e0eea09610c252381f37...   760597002
# 2  2019-05-10  2ebe392150feb60ca89caa8eff6c08b7ef1138cd6fdc71...   488561032
# 3  2019-08-26  7b3205de4ca17a339624eb5e3086698e9984eba6b47c56...   682771001
# 4  2019-08-10  3b77905de8b32045f08cedb79200cdfa477e9562429a39...   742400033
#
#       Price  Sales_Channel_Id  Month   Day_name  Revenue  Product_Code  \
# 0  0.016932                 2     11    Tuesday    16932        698328
# 1  0.033881                 2      5  Wednesday    33881        760597
# 2  0.016932                 2      5     Friday    16932        488561
# 3  0.033881                 2      8     Monday    33881        682771
# 4  0.003220                 1      8   Saturday     3220        742400
#
#          Prod_Name  ... Index_Group_Info                 Section_Info  \
# 0     ZEBRA CF TVP  ...      Divided (2)      Divided Collection (53)
# 1  BUBBLE WRAP TOP  ...   Ladieswear (1)            Womens Casual (6)
# 2    Teddy jogger.  ...     Menswear (3)     Contemporary Casual (21)
# 3     Yuki shopper  ...   Ladieswear (1)  Womens Big accessories (65)
# 4    1pk Sportsock  ...     Menswear (3)           Men Underwear (26)
#
#         Garment_Group_Info FN Active Club_Member_Status  \
# 0      Jersey Fancy (1005)  1      1             Active
# 1      Jersey Fancy (1005)  0      0             Active
# 2            Shorts (1025)  1      1             Active
# 3       Accessories (1019)  0      0             Active
# 4  Socks and Tights (1021)  0      0             Active
#
#   Fashion_News_Frequency Age Age_Group    Segment
# 0              Regularly  51        50     Top_20
# 1                   None  28        20     Middle
# 2              Regularly  37        30  Bottom_20
# 3                   None  19        10     Middle
# 4                   None  35        30     Middle
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Top 20과 Bottom 20 집단 간 총 매출 비교

# %%
segment_revenue = merged_df.groupby('Segment')['Revenue'].sum().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=segment_revenue, x='Segment', y='Revenue')
plt.title('Top 20 vs Bottom 20')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# #### Top 20, Bottom 20별 구매 채널 비교

# %%
segment_channel = merged_df.groupby(['Segment','Sales_Channel_Id']).size().unstack()  # groupby를 하면 두개 컬럼 다 행에 있는데, 피벗테이블처럼 구분하기 위해서 .unstack()을 사용해서 Channel 값을 열로 바꿔줌
segment_channel_pct = segment_channel.div(segment_channel.sum(axis=1), axis=0) * 100  # sum(axis=1)으로 여러개 열을 하나로 합침 → segment별로 sum, axis=0 기준으로 div 해서 channel별로 비율 나눔

segment_channel_pct.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Segment-Channel(%)')
plt.ylabel('Percentage(%)')
plt.legend(title='Channel (1 or 2)')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### Top 20, Bottom 20별 Fashion News 구독 여부 비교

# %%
segment_FN = merged_df.groupby(['Segment','FN']).size().unstack()  # groupby를 하면 두개 컬럼 다 행에 있는데, 피벗테이블처럼 구분하기 위해서 .unstack()을 사용해서 FN 값을 열로 바꿔줌
segment_FN_pct = segment_FN.div(segment_FN.sum(axis=1), axis=0) * 100  # sum(axis=1)으로 여러개 열을 하나로 합침 → segment별로 sum, axis=0 기준으로 div 해서 FN별로 비율 나눔

segment_FN_pct.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Segment-FN(%)')
plt.ylabel('Percentage(%)')
plt.legend(title='FN (0 or 1)')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### **전체 세그먼트 모두 비슷하게 구독:구독X == 0.4:0.6 수준으로 나와서 유의미한 결과 X**

# %% [markdown]
# ### 월별 구매 분포

# %%
monthly_revenue = merged_df.groupby('Month')['Revenue'].sum().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=monthly_revenue, x='Month', y='Revenue')
plt.title('Monthly Sales Trend')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ### 6월에 가장 많이 팔린 제품

# %%
# june_df = merged_df[merged_df['Month'] == 6]

# june_best_seller_20 = june_df.groupby('Article_Id')['Revenue'].sum().reset_index(name='Total_Revenue')
# june_best_seller_20 = june_best_seller_20.sort_values(by='Total_Revenue', ascending=False).head(20)

# %%
june_df = merged_df[merged_df['Month'] == 6]

june_best_seller_10 = june_df.groupby('Prod_Name')['Revenue'].sum().reset_index(name='Total_Revenue')
june_best_seller_10 = june_best_seller_10.sort_values(by='Total_Revenue', ascending=False).head(10)

# %%
# june_best_seller_20
# Out:
#        Article_Id  Total_Revenue
# 13485   758084002        8685009
# 13483   758064001        7648506
# 13481   758060001        5440147
# 13479   758049001        4595747
# 14441   772864001        4437773
# 13493   758138002        4408351
# 13477   758040001        3876920
# 13480   758050001        3740675
# 13486   758088002        3726176
# 13487   758089002        3689311
# 5283    656763001        3446787
# 1790    554479005        3315059
# 8545    706016002        3159317
# 13488   758110001        3085905
# 12291   744073001        2991461
# 13491   758126002        2864083
# 6537    684209004        2852898
# 13792   762630001        2821497
# 12815   749699002        2584334
# 12025   741356002        2582563

# %%
plt.figure(figsize=(25,6))
sns.barplot(data=june_best_seller_10, x=june_best_seller_10['Prod_Name'], y='Total_Revenue')

plt.title('June Best Seller 10')
plt.xlabel('Prod_Name', fontsize=12)
plt.ylabel('Total_Revenue')
plt.show()

# %% [markdown]
# ### 크리스마스 시즌에 빨간색, 녹색 제품 판매량이 늘어나는지

# %%
merged_df['Perceived_Colour_Master_Info'].value_counts()
# Out:
# Perceived_Colour_Master_Info
# Black (5)               273981
# Blue (2)                111414
# White (9)               110474
# Beige (11)               51218
# Grey (12)                46190
# Red (18)                 43761
# Pink (4)                 35029
# Green (19)               22184
# Khaki green (20)         22049
# Yellow (8)               19759
# Brown (13)               19080
# Orange (3)               17387
# Metal (15)                8828
# Mole (1)                  7704
# Unknown (-1)              5936
# Turquoise (7)             5731
# Lilac Purple (6)          2854
# undefined (14)             563
# Yellowish Green (10)         7
# Name: count, dtype: int64

# %%
filter_df = merged_df[merged_df['Perceived_Colour_Master_Info'].isin(['Red (18)', 'Green (19)'])]  # 빨강, 녹색만 필터링
red_green = filter_df.groupby('Month')['Revenue'].sum().reset_index()  # 월별 빨강, 녹색 매출
red_green
# Out:
#     Month    Revenue
# 0       1  132867829
# 1       2  109683390
# 2       3  147583164
# 3       4  164626087
# 4       5  155559915
# 5       6  160543560
# 6       7  120830150
# 7       8  101005997
# 8       9  137643872
# 9      10  156607051
# 10     11  221539299
# 11     12  148173837

# %% [markdown]
# ##### 빨간색 + 녹색 합산 매출 추이

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=red_green, x='Month', y='Revenue')
plt.title('Monthly Sales Trend: Red & Green')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# #### 빨간색, 녹색 분리 매출 추이

# %%
red_green2 = filter_df.groupby(['Month', 'Perceived_Colour_Master_Info'])['Revenue'].sum().reset_index()
red_green2.head()
# Out:
#    Month Perceived_Colour_Master_Info   Revenue
# 0      1                   Green (19)  49341610
# 1      1                     Red (18)  83526219
# 2      2                   Green (19)  43895031
# 3      2                     Red (18)  65788359
# 4      3                   Green (19)  58049838

# %%
color_map = {'Red (18)': "#FF0000B7", 'Green (19)': "#065E00A7"}

plt.figure(figsize=(18, 6))
sns.barplot(data=red_green2, x='Month', y='Revenue', hue='Perceived_Colour_Master_Info', palette=color_map)
plt.title('Monthly Sales Trend: Red | Green')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ### 11월에 빨간색, 녹색 어떤 제품들이 판매되었는지

# %%
nov_red_green_filter = filter_df[(filter_df['Month'] == 11) & (filter_df['Perceived_Colour_Master_Info'].isin(['Red (18)', 'Green (19)']))]
nov_red_green = nov_red_green_filter.groupby('Product_Group_Name')['Revenue'].sum().sort_values(ascending=False).reset_index()
nov_red_green
# Out:
#    Product_Group_Name    Revenue
# 0  Garment Upper body  102026696
# 1   Garment Full body   46639299
# 2  Garment Lower body   31700726
# 3           Underwear   29440112
# 4           Nightwear    4263325
# 5         Accessories    3892411
# 6      Socks & Tights    1405574
# 7            Swimwear    1177765
# 8               Shoes     993391

# %%
plt.figure(figsize=(18, 6))
sns.barplot(data=nov_red_green, x='Product_Group_Name', y='Revenue')
plt.title('November Sales Trend: Red & Green')
plt.xlabel('Product Group')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ### 11월에 매출이 높은 이유가 블랙 프라이데이 할인 때문일까? 아니면 크리스마스 특수성 때문일까?

# %%
months = filter_df[filter_df['Month'].isin([6, 11])]

monthly_avg_price = months.groupby('Month')['Price'].mean().reset_index()
monthly_avg_price
# Out:
#    Month     Price
# 0      6  0.024914
# 1     11  0.031269

# %%
plt.figure(figsize=(6, 5))
sns.barplot(data=monthly_avg_price, x='Month', y='Price')
plt.title('Monthly Average Price: June vs November')
plt.xlabel('Month')
plt.ylabel('Avg Price')
plt.show()

# %% [markdown]
# ### transactions에서의 1개의 행 == 1개의 구매라고 가정하면? (여러개 사면 여러개 행으로)

# %%
quantity = months.groupby('Month').size().reset_index(name='Quantity')
quantity
# Out:
#    Month  Quantity
# 0      6      6444
# 1     11      7085

# %%
plt.figure(figsize=(6, 5))
sns.barplot(data=quantity, x='Month', y='Quantity')
plt.title('Monthly Quantity: June vs November')
plt.xlabel('Month')
plt.ylabel('Quantity')
plt.show()

# %% [markdown]
# ### 다른 색상 대비 빨강, 녹색의 판매 비율 변화 확인

# %%
monthly_revenue = merged_df.groupby('Month')['Revenue'].sum().reset_index(name='Total_Revenue')  # 전체 색상 월별 매출

red_green = filter_df.groupby('Month')['Revenue'].sum().reset_index(name='Red_Green_Revenue')  # 월별 빨강, 녹색 매출

rate_df = pd.merge(monthly_revenue, red_green, on='Month')
rate_df['Red_Green_Pct'] = (rate_df['Red_Green_Revenue']) / (rate_df['Total_Revenue']) * 100
rate_df.head()
# Out:
#    Month  Total_Revenue  Red_Green_Revenue  Red_Green_Pct
# 0      1     1594590055          132867829       8.332413
# 1      2     1511379220          109683390       7.257172
# 2      3     1782262330          147583164       8.280664
# 3      4     2047003489          164626087       8.042296
# 4      5     2085704025          155559915       7.458389

# %%
red_green_avg_rate = rate_df['Red_Green_Pct'].mean()
red_green_avg_rate
# Out:
# np.float64(8.259547193400865)

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(data=rate_df, x='Month', y='Red_Green_Pct')
ax.axhline(red_green_avg_rate, color='red', linestyle='--', linewidth=2, label=f'Average: {red_green_avg_rate:.2f}%')
plt.title('Monthly Red & Green Rate(%)')
plt.xlabel('Month')
plt.ylabel('Red & Green Rate')
plt.legend() # 라벨 표시
plt.show()

# %% [markdown]
# #### 11월의 매출 급증은 블랙 프라이데이 할인 때문이라기 보다는
# #### **평균가가 높은 겨울 의류(시즌 아이템)** 가 더 많이 팔리는 **크리스마스 특수** 영향?

# %%
pd.set_option('display.max_columns', None)
filter_df.head()
# Out:
#          T_Dat                                        Customer_Id  Article_Id  \
# 7   2019-02-22  4c8c418805d81bd1d25d77659f227ac5570b154172ff8c...   651685004
# 16  2019-07-22  8dab58de0006949327178882f1a746df8080ba76ded63d...   689005002
# 18  2019-07-30  49048795f6ce5af65ace68d191e97f046549df660ba1fc...   694618002
# 32  2019-05-15  8c4b4526a5c10f1dac42583e661f059329bdbc85142fa5...   723173006
# 34  2019-12-21  41da9113f20586073dcd11a08f0afb1ec363a2a5d4ff34...   698328007
#
#        Price  Sales_Channel_Id  Month   Day_name  Revenue  Product_Code  \
# 7   0.016932                 2      2     Friday    16932        651685
# 16  0.016932                 2      7     Monday    16932        689005
# 18  0.022017                 2      7    Tuesday    22016        694618
# 32  0.021508                 2      5  Wednesday    21508        723173
# 34  0.004559                 1     12   Saturday     4559        698328
#
#            Prod_Name    Product_Type_Info  Product_Group_Name  \
# 7     Hazel playsuit       Trousers (272)  Garment Lower body
# 16     Walk Away Top     Bikini top (298)            Swimwear
# 18  Penny sandalette  Heeled sandals (92)               Shoes
# 32         SPEARMINT       Vest top (253)  Garment Upper body
# 34      ZEBRA CF TVP        Sweater (252)  Garment Upper body
#
#      Graphical_Appearance_Info Perceived_Colour_Master_Info  \
# 7   All over pattern (1010001)                     Red (18)
# 16             Solid (1010016)                   Green (19)
# 18             Solid (1010016)                     Red (18)
# 32             Solid (1010016)                   Green (19)
# 34        Embroidery (1010007)                     Red (18)
#
#              Department_Info              Index_Info Index_Group_Info  \
# 7             Trouser (1722)          Ladieswear (A)   Ladieswear (1)
# 16           Swimwear (4242)    Lingeries/Tights (B)   Ladieswear (1)
# 18              Heels (3528)  Ladies Accessories (C)   Ladieswear (1)
# 32         Tops Woven (1543)             Divided (D)      Divided (2)
# 34  Tops Fancy Jersey (1640)             Divided (D)      Divided (2)
#
#                        Section_Info   Garment_Group_Info  FN  Active  \
# 7   Womens Everyday Collection (15)      Trousers (1009)   0       0
# 16  Womens Swimwear, beachwear (60)      Swimwear (1018)   0       0
# 18                Womens Shoes (64)         Shoes (1020)   0       0
# 32          Divided Collection (53)       Blouses (1010)   0       0
# 34          Divided Collection (53)  Jersey Fancy (1005)   0       0
#
#    Club_Member_Status Fashion_News_Frequency  Age  Age_Group    Segment
# 7              Active                   None   26         20  Bottom_20
# 16             Active                   None   26         20     Top_20
# 18             Active                   None   55         50     Top_20
# 32             Active                   None   46         40     Middle
# 34             Active                   None   23         20  Bottom_20

# %% [markdown]
# ### 월별&연령대별 빨강, 녹색 제품 구매 비율

# %%
monthly_revenue = merged_df.groupby('Month')['Revenue'].sum().reset_index()
filter_df = merged_df[merged_df['Perceived_Colour_Master_Info'].isin(['Red (18)', 'Green (19)'])]  # 빨강, 녹색만 필터링
red_green = filter_df.groupby('Month')['Revenue'].sum().reset_index()  # 월별 빨강, 녹색 매출

# %%
monthly_revenue = merged_df.groupby('Month')['Revenue'].sum().reset_index(name='Total_Revenue')  # 전체 색상 월별 매출

red_green = filter_df.groupby('Month')['Revenue'].sum().reset_index(name='Red_Green_Revenue')  # 월별 빨강, 녹색 매출

rate_df = pd.merge(monthly_revenue, red_green, on='Month')
rate_df['Red_Green_Pct'] = (rate_df['Red_Green_Revenue']) / (rate_df['Total_Revenue']) * 100
rate_df.head()
# Out:
#    Month  Total_Revenue  Red_Green_Revenue  Red_Green_Pct
# 0      1     1594590055          132867829       8.332413
# 1      2     1511379220          109683390       7.257172
# 2      3     1782262330          147583164       8.280664
# 3      4     2047003489          164626087       8.042296
# 4      5     2085704025          155559915       7.458389

# %% [markdown]
# 계산

# %%
red_green = filter_df.groupby('Month')['Revenue'].sum().reset_index(name='Red_Green_Revenue')  # 월별 빨강, 녹색 매출
monthly_age_df = filter_df.groupby(['Month','Age_Group'])['Revenue'].sum().reset_index(name='Red_Green_Age')  # 월별&연령별 빨강, 녹색 매출
monthly_age_df
# Out:
#     Month  Age_Group  Red_Green_Age
# 0       1         10        1560009
# 1       1         20       54359944
# 2       1         30       27964744
# 3       1         40       20876386
# 4       1         50       21430507
# ..    ...        ...            ...
# 67     12         20       63052675
# 68     12         30       29665561
# 69     12         40       20917129
# 70     12         50       25498321
# 71     12         60        6996029
#
# [72 rows x 3 columns]

# %%
rate_df2 = pd.merge(red_green, monthly_age_df, on='Month')
rate_df2['Red_Green_Age_Pct'] = (rate_df2['Red_Green_Age']) / (rate_df2['Red_Green_Revenue']) * 100
rate_df2.head()
# Out:
#    Month  Red_Green_Revenue  Age_Group  Red_Green_Age  Red_Green_Age_Pct
# 0      1          132867829         10        1560009           1.174106
# 1      1          132867829         20       54359944          40.912796
# 2      1          132867829         30       27964744          21.047039
# 3      1          132867829         40       20876386          15.712145
# 4      1          132867829         50       21430507          16.129192

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=rate_df2, x='Month', y='Red_Green_Age_Pct', hue='Age_Group')
plt.title('Monthly-Age Group Red & Green Rate(%)')
plt.xlabel('Month')
plt.ylabel('Red & Green Rate')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.show()
