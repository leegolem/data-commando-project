# %% [markdown]
# # articles_hm 전처리

# %%
import pandas as pd
articles = pd.read_csv("../../main/h&m_dataset/articles_hm.csv")
articles.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# ...

# %%
articles.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  str
#  3   product_type_no               105542 non-null  int64
#  4   product_type_name             105542 non-null  str
#  5   product_group_name            105542 non-null  str
#  6   graphical_appearance_no       105542 non-null  int64
#  7   graphical_appearance_name     105542 non-null  str
#  8   colour_group_code             105542 non-null  int64
#  9   colour_group_name             105542 non-null  str
#  10  perceived_colour_value_id     105542 non-null  int64
#  11  perceived_colour_value_name   105542 non-null  str
#  12  perceived_colour_master_id    105542 non-null  int64
# ...

# %%
articles.shape
# Out:
# (105542, 25)

# %%
na_c = articles.isna().sum().sort_values(ascending=False) 
na_c.head(3)
# Out:
# detail_desc     416
# product_code      0
# prod_name         0
# dtype: int64

# %% [markdown]
# # 전처리 작업

# %% [markdown]
# - article_id                    # 상품을 식별하는 ID
# - product_code                  # 상품 코드
# - prod_name                     # 상품 이름

# %% [markdown]
# - 상품 분류 (가장 중요)
#     - product_type_no	            # 상품 유형 코드
#     - product_type_name	            # 상품 유형 명 - “T-shirt”, “Dress”
#     - product_group_name            # 상품 대분류 - “Garment Upper body”
#
# - 상품군
#     - garment_group_no	            # 의류 그룹 코드
#     - garment_group_name	        # 의류 그룹 이름 - “Jersey Basic”
#
# - 카테고리(상위)
#     - index_group_no                # 판매 인덱스 그룹 코드
#     - index_group_name              # 성별·연령대 기반 그룹 - “Ladieswear”, “Menswear”
#
# - 타깃 관련
#     - index_code                    # 중분류 코드
#     - index_name                    # 중분류 명 (예: Lingeries/Tights)
#
# - 판매 섹션
#     - section_no                    # 섹션 코드
#     - section_name                  # 실제 판매 섹션 - “Womens Everyday Basics”
#
# - 부서
#     - department_no                 # 내부 부서 코드
#     - department_name               # 부서 이름 - 보조적 상품 분류

# %% [markdown]
# - 디자인
#     - graphical_appearance_no       # 외형 정보 코드
#     - graphical_appearance_name     # 외형 스타일 - “Solid”, “All over pattern”
#
# - 색상
#     - colour_group_code             # 색상 그룹 코드
#     - colour_group_name             # 상품 색상 명 - “Black”, “White”
#
# - 명도
#     - perceived_colour_value_id     # 색 밝기/톤 코드 - 명도 분류
#     - perceived_colour_value_name   # 밝기 느낌 - “Dark”, “Light”
#
# - 색 계열 코드
#     - perceived_colour_master_id    # 색 계열 코드
#     - perceived_colour_master_name  # 색 계열 이름 - “Black”, “Blue”

# %% [markdown]
# ##### 제거할 컬럼
# - *_no, *_code
#     - 가독성이 매우 낮고 name 컬럼들과 중복됨
# - department_*
#     - 부서 분류까지 갈 필요성 X
# - prod_name   # 생각 보류
#     - 변수로 사용하기 애매하지만 설명용으로 사용 가능 예상

# %% [markdown]
# ##### 반드시 필요하다 판단한 컬럼
# - article_id
#     - 거래 데이터와 조인하는 키
# - product_group_name
#     - 상품 분류, 가장 큰 분류
# - garment_group_name
#     - 의류 대분류, 구매 패턴 비교에 필요
# - index_group_name
#     - 타겟 그룹(Ladies/Mens 등), 고객군 해석에 필요하다 판단
# - section_name
#     - 실제 매장/서비스 단위, 실무 해석 필요하다 판단

# %%
art = articles.copy()

# %% [markdown]
# ### 필요없는 컬럼 제거

# %%
art_drop = art.drop('detail_desc', axis=1)
art_drop.isna().sum()
# Out:
# article_id                      0
# product_code                    0
# prod_name                       0
# product_type_no                 0
# product_type_name               0
# product_group_name              0
# graphical_appearance_no         0
# graphical_appearance_name       0
# colour_group_code               0
# colour_group_name               0
# perceived_colour_value_id       0
# perceived_colour_value_name     0
# perceived_colour_master_id      0
# perceived_colour_master_name    0
# department_no                   0
# department_name                 0
# index_code                      0
# index_name                      0
# index_group_no                  0
# index_group_name                0
# section_no                      0
# section_name                    0
# garment_group_no                0
# garment_group_name              0
# dtype: int64

# %% [markdown]
# ### 제품 색상 코드 컬럼 정리

# %% [markdown]
# 제품 색상 코드를 나타내는 컬럼이 'colour_group_code', 'colour_group_name', 'perceived_colour_value_id', 'perceived_colour_value_name', 'perceived_colour_master_id', 'perceived_colour_master_name'  로 총 6개 <br>
# 데이터를 단순화 하기 위해 'perceived_colour_master_id', 'perceived_colour_master_name' 2개 컬럼을 대표로 사용하고 나머지 컬럼은 삭제한다

# %%
art_drop = art_drop.drop(['colour_group_code', 'colour_group_name', 'perceived_colour_value_id', 'perceived_colour_value_name'], axis=1)
art_drop.columns
# Out:
# Index(['article_id', 'product_code', 'prod_name', 'product_type_no',
#        'product_type_name', 'product_group_name', 'graphical_appearance_no',
#        'graphical_appearance_name', 'perceived_colour_master_id',
#        'perceived_colour_master_name', 'department_no', 'department_name',
#        'index_code', 'index_name', 'index_group_no', 'index_group_name',
#        'section_no', 'section_name', 'garment_group_no', 'garment_group_name'],
#       dtype='str')

# %%
art_drop.isna().sum()
# Out:
# article_id                      0
# product_code                    0
# prod_name                       0
# product_type_no                 0
# product_type_name               0
# product_group_name              0
# graphical_appearance_no         0
# graphical_appearance_name       0
# perceived_colour_master_id      0
# perceived_colour_master_name    0
# department_no                   0
# department_name                 0
# index_code                      0
# index_name                      0
# index_group_no                  0
# index_group_name                0
# section_no                      0
# section_name                    0
# garment_group_no                0
# garment_group_name              0
# dtype: int64

# %% [markdown]
# ### 컬럼 고유값 확인

# %% [markdown]
# #### product type

# %%
art_drop[['product_type_no', 'product_type_name']].value_counts()
# Out:
# product_type_no  product_type_name
# 272              Trousers             11169
# 265              Dress                10362
# 252              Sweater               9302
# 255              T-shirt               7904
# 254              Top                   4155
#                                       ...
# 366              Towel                    1
# 493              Wood balls               1
# 464              Pre-walkers              1
# 468              Bumbag                   1
# 483              Clothing mist            1
# Name: count, Length: 132, dtype: int64

# %%
check = art_drop.groupby('product_type_no')['product_type_name'].nunique()
print(check[check > 1])
# Out:
# Series([], Name: product_type_name, dtype: int64)

# %% [markdown]
# product_type_no == product_type_name 깔끔하게 서로 매칭됨 → 두 컬럼을 하나로 합치는 파생 컬럼 생성

# %%
art_drop['product_type_info'] = art_drop['product_type_name'] + " (" + art_drop['product_type_no'].astype(str) + ")"
art_drop.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  perceived_colour_master_id  \
# 0                     Solid                           5
# 1                     Solid                           9
# ...

# %% [markdown]
# #### graphical_appearance

# %%
art_drop[['graphical_appearance_no', 'graphical_appearance_name']].value_counts()
# Out:
# graphical_appearance_no  graphical_appearance_name
#  1010016                 Solid                        49747
#  1010001                 All over pattern             17165
#  1010010                 Melange                       5938
#  1010017                 Stripe                        4990
#  1010023                 Denim                         4842
#  1010008                 Front print                   3215
#  1010014                 Placement print               3098
#  1010004                 Check                         2178
#  1010005                 Colour blocking               1830
#  1010021                 Lace                          1513
#  1010026                 Other structure               1502
#  1010002                 Application/3D                1341
#  1010007                 Embroidery                    1165
#  1010012                 Mixed solid/pattern           1132
#  1010009                 Glittering/Metallic            958
# ...

# %%
check2 = art_drop.groupby('graphical_appearance_no')['graphical_appearance_name'].nunique()
print(check2[check2 > 1])
# Out:
# Series([], Name: graphical_appearance_name, dtype: int64)

# %% [markdown]
# graphical_appearance_no == graphical_appearance_name 깔끔하게 서로 매칭됨 → 두 컬럼을 하나로 합치는 파생 컬럼 생성

# %%
art_drop['graphical_appearance_info'] = art_drop['graphical_appearance_name'] + " (" + art_drop['graphical_appearance_no'].astype(str) + ")"
art_drop.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  perceived_colour_master_id  \
# 0                     Solid                           5
# 1                     Solid                           9
# ...

# %% [markdown]
# #### perceived_colour_master

# %%
art_drop[['perceived_colour_master_id', 'perceived_colour_master_name']].value_counts()
# Out:
# perceived_colour_master_id  perceived_colour_master_name
#  5                          Black                           22585
#  2                          Blue                            18469
#  9                          White                           12665
#  4                          Pink                             9403
#  12                         Grey                             8924
#  18                         Red                              5878
#  11                         Beige                            5657
#  19                         Green                            3526
#  20                         Khaki green                      3181
#  8                          Yellow                           3121
#  3                          Orange                           2734
#  13                         Brown                            2269
#  15                         Metal                            2180
# ...

# %%
check3 = art_drop.groupby('perceived_colour_master_id')['perceived_colour_master_name'].nunique()
print(check3[check3 > 1])
# Out:
# Series([], Name: perceived_colour_master_name, dtype: int64)

# %% [markdown]
# perceived_colour_master_id == perceived_colour_master_name 깔끔하게 서로 매칭됨 → 두 컬럼을 하나로 합치는 파생 컬럼 생성

# %%
art_drop['perceived_colour_master_info'] = art_drop['perceived_colour_master_name'] + " (" + art_drop['perceived_colour_master_id'].astype(str) + ")"
art_drop.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  perceived_colour_master_id  \
# 0                     Solid                           5
# 1                     Solid                           9
# ...

# %% [markdown]
# #### department

# %%
art_drop[['department_no', 'department_name']].value_counts()
# Out:
# department_no  department_name
# 7616           Kids Girl Jersey Fancy             2032
# 1338           Expressive Lingerie                1921
# 8716           Young Girl Jersey Fancy            1874
# 4242           Swimwear                           1839
# 7648           Kids Boy Jersey Fancy              1488
#                                                   ...
# 5787           Shirt Extended inactive from s1       1
# 7659           Kids Boy License                      1
# 1620           Jersey inactive from S.6              1
# 3943           EQ Divided Blue                       1
# 3931           Accessories Other                     1
# Name: count, Length: 299, dtype: int64

# %%
check4 = art_drop.groupby('department_no')['department_name'].nunique()
print(check4[check4 > 1])
# Out:
# Series([], Name: department_name, dtype: int64)

# %% [markdown]
# department_no == department_name 깔끔하게 서로 매칭됨 → 두 컬럼을 하나로 합치는 파생 컬럼 생성

# %%
art_drop['department_info'] = art_drop['department_name'] + " (" + art_drop['department_no'].astype(str) + ")"
art_drop.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  perceived_colour_master_id  \
# 0                     Solid                           5
# 1                     Solid                           9
# ...

# %% [markdown]
# #### index

# %%
art_drop[['index_code', 'index_name']].value_counts()
# Out:
# index_code  index_name
# A           Ladieswear                        26001
# D           Divided                           15149
# F           Menswear                          12553
# H           Children Sizes 92-140             12007
# I           Children Sizes 134-170             9214
# G           Baby Sizes 50-98                   8875
# C           Ladies Accessories                 6961
# B           Lingeries/Tights                   6775
# J           Children Accessories, Swimwear     4615
# S           Sport                              3392
# Name: count, dtype: int64

# %%
check5 = art_drop.groupby('index_code')['index_name'].nunique()
print(check5[check5 > 1])
# Out:
# Series([], Name: index_name, dtype: int64)

# %% [markdown]
# art_drop.

# %% [markdown]
# index_code == index_name 깔끔하게 서로 매칭됨 → 두 컬럼을 하나로 합치는 파생 컬럼 생성

# %%
art_drop['index_info'] = art_drop['index_name'] + " (" + art_drop['index_code'].astype(str) + ")"
art_drop.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  perceived_colour_master_id  \
# 0                     Solid                           5
# 1                     Solid                           9
# ...

# %% [markdown]
# #### index_group_no

# %%
art_drop[['index_group_no', 'index_group_name']].value_counts()
# Out:
# index_group_no  index_group_name
# 1               Ladieswear          39737
# 4               Baby/Children       34711
# 2               Divided             15149
# 3               Menswear            12553
# 26              Sport                3392
# Name: count, dtype: int64

# %%
check5 = art_drop.groupby('index_group_no')['index_group_name'].nunique()
print(check5[check5 > 1])
# Out:
# Series([], Name: index_group_name, dtype: int64)

# %% [markdown]
# index_group_no == index_group_name 깔끔하게 서로 매칭됨 → 두 컬럼을 하나로 합치는 파생 컬럼 생성

# %%
art_drop['index_group_info'] = art_drop['index_group_name'] + " (" + art_drop['index_group_no'].astype(str) + ")"
art_drop.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  perceived_colour_master_id  \
# 0                     Solid                           5
# 1                     Solid                           9
# ...

# %% [markdown]
# #### section

# %%
art_drop[['section_no', 'section_name']].value_counts()
# Out:
# section_no  section_name
# 15          Womens Everyday Collection        7295
# 53          Divided Collection                7124
# 44          Baby Essentials & Complements     4932
# 76          Kids Girl                         4469
# 77          Young Girl                        3899
# 61          Womens Lingerie                   3598
# 79          Girls Underwear & Basics          3490
# 11          Womens Tailoring                  3376
# 46          Kids Boy                          3328
# 66          Womens Small accessories          3270
# 6           Womens Casual                     2725
# 45          Kids Outerwear                    2665
# 18          Womens Trend                      2622
# 50          Divided Projects                  2364
# 47          Young Boy                         2352
# 2           H&M+                              2337
# 26          Men Underwear                     2322
# 8           Mama                              2266
# ...

# %%
check6 = art_drop.groupby('section_no')['section_name'].nunique()
print(check6[check6 > 1])
# Out:
# Series([], Name: section_name, dtype: int64)

# %% [markdown]
# section_no == section_name 깔끔하게 서로 매칭됨 → 두 컬럼을 하나로 합치는 파생 컬럼 생성

# %%
art_drop['section_info'] = art_drop['section_name'] + " (" + art_drop['section_no'].astype(str) + ")"
art_drop.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  perceived_colour_master_id  \
# 0                     Solid                           5
# 1                     Solid                           9
# ...

# %% [markdown]
# #### garment_group

# %%
art_drop[['garment_group_no', 'garment_group_name']].value_counts()
# Out:
# garment_group_no  garment_group_name
# 1005              Jersey Fancy                     21445
# 1019              Accessories                      11519
# 1002              Jersey Basic                      8126
# 1003              Knitwear                          7490
# 1017              Under-, Nightwear                 7441
# 1009              Trousers                          6727
# 1010              Blouses                           5838
# 1020              Shoes                             5145
# 1013              Dresses Ladies                    4874
# 1007              Outdoor                           4501
# 1001              Unknown                           3873
# 1016              Trousers Denim                    3100
# 1018              Swimwear                          2787
# 1021              Socks and Tights                  2272
# 1011              Shirts                            2116
# 1006              Woven/Jersey/Knitted mix Baby     1965
# ...

# %%
check7 = art_drop.groupby('garment_group_no')['garment_group_name'].nunique()
print(check7[check7 > 1])
# Out:
# Series([], Name: garment_group_name, dtype: int64)

# %% [markdown]
# garment_group_no == garment_group_name 깔끔하게 서로 매칭됨 → 두 컬럼을 하나로 합치는 파생 컬럼 생성

# %%
art_drop['garment_group_info'] = art_drop['garment_group_name'] + " (" + art_drop['garment_group_no'].astype(str) + ")"
art_drop.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  perceived_colour_master_id  \
# 0                     Solid                           5
# 1                     Solid                           9
# ...

# %% [markdown]
# ### 요약한 컬럼을 활용해 df 생성

# %%
new_art = art_drop[['article_id', 'product_code', 'prod_name', 'product_type_info', 'product_group_name', 'graphical_appearance_info', 'perceived_colour_master_info', 'department_info',	'index_info', 'index_group_info', 'section_info', 'garment_group_info']]
new_art.columns
# Out:
# Index(['article_id', 'product_code', 'prod_name', 'product_type_info',
#        'product_group_name', 'graphical_appearance_info',
#        'perceived_colour_master_info', 'department_info', 'index_info',
#        'index_group_info', 'section_info', 'garment_group_info'],
#       dtype='str')

# %%
new_art.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  str
#  3   product_type_info             105542 non-null  str
#  4   product_group_name            105542 non-null  str
#  5   graphical_appearance_info     105542 non-null  str
#  6   perceived_colour_master_info  105542 non-null  str
#  7   department_info               105542 non-null  str
#  8   index_info                    105542 non-null  str
#  9   index_group_info              105542 non-null  str
#  10  section_info                  105542 non-null  str
#  11  garment_group_info            105542 non-null  str
# dtypes: int64(2), str(10)
# memory usage: 9.7 MB

# %%
new_art.shape
# Out:
# (105542, 12)

# %% [markdown]
# ## 최종확인

# %%
new_art.head()
# Out:
#    article_id  product_code          prod_name product_type_info  \
# 0   108775015        108775          Strap top    Vest top (253)
# 1   108775044        108775          Strap top    Vest top (253)
# 2   108775051        108775      Strap top (1)    Vest top (253)
# 3   110065001        110065  OP T-shirt (Idro)         Bra (306)
# 4   110065002        110065  OP T-shirt (Idro)         Bra (306)
#
#    product_group_name graphical_appearance_info perceived_colour_master_info  \
# 0  Garment Upper body           Solid (1010016)                    Black (5)
# 1  Garment Upper body           Solid (1010016)                    White (9)
# 2  Garment Upper body          Stripe (1010017)                    White (9)
# 3           Underwear           Solid (1010016)                    Black (5)
# 4           Underwear           Solid (1010016)                    White (9)
#
#          department_info            index_info index_group_info  \
# ...

# %%
new_art.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 105542 entries, 0 to 105541
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   article_id                    105542 non-null  int64
#  1   product_code                  105542 non-null  int64
#  2   prod_name                     105542 non-null  str
#  3   product_type_info             105542 non-null  str
#  4   product_group_name            105542 non-null  str
#  5   graphical_appearance_info     105542 non-null  str
#  6   perceived_colour_master_info  105542 non-null  str
#  7   department_info               105542 non-null  str
#  8   index_info                    105542 non-null  str
#  9   index_group_info              105542 non-null  str
#  10  section_info                  105542 non-null  str
#  11  garment_group_info            105542 non-null  str
# dtypes: int64(2), str(10)
# memory usage: 9.7 MB

# %%
new_art.shape
# Out:
# (105542, 12)

# %%
new_art.isna().sum()
# Out:
# article_id                      0
# product_code                    0
# prod_name                       0
# product_type_info               0
# product_group_name              0
# graphical_appearance_info       0
# perceived_colour_master_info    0
# department_info                 0
# index_info                      0
# index_group_info                0
# section_info                    0
# garment_group_info              0
# dtype: int64

# %% [markdown]
# - article_id              : 개별 상품을 식별하는 고유 ID
# - product_code            : 동일한 디자인·모델을 묶는 상품 그룹 코드
# - prod_name               : 상품 이름
# - product_type_info       : 상품 유형을 나타내는 메타데이터
# - product_group_name      : 상품 분류 메타데이터
# - garment_group_info      : 의류 그룹 메타데이터
# - index_group_info        : 타겟 고객군 메타데이터
# - index_info              : index_group의 세부 라인/컬렉션 메타데이터
# - section_info            : 판매 섹션 메타데이터
# - department_info         : 부서 메타데이터
# - perceived_colour_master_info  : 색상군 메타데이터
# - graphical_appearance_info     : 외형 메타데이터

# %%
new_art.to_csv("data/articles_processed.csv", index=False, encoding="utf-8-sig")
